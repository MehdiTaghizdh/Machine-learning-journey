# %%
import numpy as np

# %%
z=np.array ([[1,2,3],
             [4,5,6]])

# %%
print (z.sum())
# Out:
# 21

# %%
z.sum()
# Out:
# np.int64(21)

# %%
type(z)
# Out:
# numpy.ndarray

# %%
print(z.sum(axis=0))
# Out:
# [5 7 9]

# %%
print(z.sum(axis=1))
# Out:
# [ 6 15]

# %%
f=np.array([
           [10,20,30],
           [40,50,60],
           [70,80,90]
           ])

# %%
print (f.sum())
# Out:
# 450

# %%
print (f.sum(0))
# Out:
# [120 150 180]

# %%
print(f.sum(1))
# Out:
# [ 60 150 240]

# %%
k=np.array ([1,2,3,4,5,6])

# %%
print (k>3)
# Out:
# [False False False  True  True  True]

# %%
k>3
# Out:
# array([False, False, False,  True,  True,  True])

# %%
print (k[k>3])
# Out:
# [4 5 6]

# %%
print (k[k % 2 ==0])
# Out:
# [2 4 6]

# %%
print (k[k>4])
# Out:
# [5 6]

# %%
print (k[(k>2)&(k<6)])
# Out:
# [3 4 5]

# %%
j = np.array([10,15,20,25,30,35])

# %%
print (j[j >= 20])
print (j[j % 10 == 0])
print (j[(j>15)&(j<35)])
# Out:
# [20 25 30 35]
# [10 20 30]
# [20 25 30]

# %%
##lets practice random in numpy

# %%
import numpy as np

# %%
print(np.random.randint(1,10,5))
# Out:
# [6 8 1 4 2]

# %%
a=(np.random.randint(1,6,1))
print(a)
# Out:
# [1]

# %%
print(np.random.rand(5))
# Out:
# [0.82808736 0.86110737 0.40730615 0.07319586 0.67620471]

# %%
print (np.random.randn(5))
# Out:
# [ 0.81078832  0.73450743 -0.73855172 -0.3828431   1.18662874]

# %%
grades = np.random.randint(0,21,20)
print(grades)
# Out:
# [14 13  6  6  2  5  6 15  4  4  6 19  9  2  0  4  2 18 12  1]

# %%
grades = np.random.randint(0,21,20)
print(grades[grades >=10])
# Out:
# [14 17 19 20 20 14 18 11 17 14 18]

# %%
a=np.random.randint(50,101,10)
print(a)
# Out:
# [ 53  50  85  66 100  59  93  84  78  74]

# %%
a=np.random.randint(50,101,10)
print(a)
print (a[a>=80])
# Out:
# [65 98 81 87 51 97 79 87 53 79]
# [98 81 87 97 87]
