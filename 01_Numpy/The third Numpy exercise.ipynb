# %%
import numpy as np

# %%
grades = np.array([10,15,20,18,12])
print(grades)
# Out:
# [10 15 20 18 12]

# %%
print(grades.mean())
# Out:
# 15.0

# %%
print(grades.max())
# Out:
# 20

# %%
print(grades.min())
# Out:
# 10

# %%
print(grades.sum())
# Out:
# 75

# %%
print(grades.std())
# Out:
# 3.687817782917155

# %%
q = np.array([2,4,6,8,10])
print(q.mean())
print(q.max())
print(q.min())
print(q.sum())
# Out:
# 6.0
# 10
# 2
# 30

# %%
np.random.seed(42)
a=(np.random.randint(1,21,100))
print(a)
print(a.sum())
print(a.mean())

print(a.max())

print(a.min())

print(a.std())

print(a[a>=10]) 

print(sum(a>=10))
# Out:
# [ 7 20 15 11  8  7 19 11 11  4  8  3  2 12  6  2  1 12 12 17 10 16 15 15
#  19 12 20  3  5 19  7  9  7 18  4 14 18  9  2 20 15  7 12  8 15  3 14 17
#   4 18  8  4  2  6 10  4 18 12  2 10  4 14 16 15  8 14  8 16 13 18 15 13
#   9 15 13  1  7  9  1 12  8 11 19 17  8  3  3  1  5 10  7  9  7  9  8 12
#   2  1 16  5]
# 1001
# 10.01
# 20
# 1
# 5.507258846286417
# [20 15 11 19 11 11 12 12 12 17 10 16 15 15 19 12 20 19 18 14 18 20 15 12
#  15 14 17 18 10 18 12 10 14 16 15 14 16 13 18 15 13 15 13 12 11 19 17 10
#  12 16]
# 50

# %%
import numpy as np

# %%
a = np.array([1,2,3])

# %%
b=a

# %%
b[0] = 99

# %%
print(a,b)
# Out:
# [99  2  3] [99  2  3]

# %%
a = np.array([1,2,3])

# %%
b = a.copy()

# %%
b[0] = 99

# %%
print (a,b)
# Out:
# [1 2 3] [99  2  3]
