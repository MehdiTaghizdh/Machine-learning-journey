# %% [markdown]
# pandas training with jeson brownlee

# %%
import numpy as np
import pandas as pd

# %%
my_array = np.array([1,2,3])

# %%
row_names = ['a','b','c']

# %%
my_series = pd.Series(my_array, index = row_names)

# %%
print(my_series)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
print(my_series[0])
# Out:
# 1
# C:\Users\4-063-p-jomboze\AppData\Local\Temp\ipykernel_6468\739979572.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(my_series[0])

# %%
print(my_series[1])
# Out:
# 2
# C:\Users\4-063-p-jomboze\AppData\Local\Temp\ipykernel_6468\2700731362.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(my_series[1])

# %%
print(my_series.iloc[2])
# Out:
# 3

# %%
print(my_series.loc['a'])
# Out:
# 1

# %%
#make a dataframe

# %%
import numpy as np
import pandas as nd
myarray = np.array([
          [1,2,3],
          [4,5,6]
])
rownames = ['a' , 'b']
colnames = ['one','two','tree']
df = pd.DataFrame(myarray, index=rownames, columns = colnames)
df
# Out:
#    one  two  tree
# a    1    2     3
# b    4    5     6

# %%
myarray = np.array([
          [13,145,45],
          [40,158,60],
          [29,175,95],
          [35,186,79]
    
])
rownames = ['ali' , 'bahram', 'saeed', 'mehdi']
colnames = ['age','height', 'weight']
new_df = pd.DataFrame(myarray, index=rownames, columns = colnames)
new_df
# Out:
#         age  height  weight
# ali      13     145      45
# bahram   40     158      60
# saeed    29     175      95
# mehdi    35     186      79
